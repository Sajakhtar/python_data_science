# %% [markdown]
# # Style and Color
#
# We've shown a few times how to control figure aesthetics in seaborn, but let's now go over it formally:

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## Styles
#
# You can set particular styles:

# %%
sns.countplot(x='sex', data=tips, palette='deep')

# %%
# set style for all plots
sns.set_style(style='white')
sns.countplot(x='sex', data=tips, palette='deep')

# %%
sns.set_style(style='dark')
sns.countplot(x='sex', data=tips, palette='deep')

# %%
sns.set_style(style='ticks')
sns.countplot(x='sex', data=tips, palette='deep')

# %%
sns.set_style(style='darkgrid')
sns.countplot(x='sex', data=tips, palette='deep')

# %%
sns.set_style(style='whitegrid')
sns.countplot(x='sex', data=tips, palette='deep')

# %% [markdown]
# ## Spine Removal

# %%
sns.set_style(style='ticks')
sns.countplot(x='sex', data=tips, palette='deep')
sns.despine()

# %%
sns.set_style(style='ticks')
sns.countplot(x='sex', data=tips, palette='deep')
sns.despine(left=True) # true to removeS

# %%
sns.set_style(style='ticks')
sns.countplot(x='sex', data=tips, palette='deep')
sns.despine(left=True, bottom=True)

# %% [markdown]
# ## Size and Aspect

# %% [markdown]
# You can use matplotlib's **plt.figure(figsize=(width,height) ** to change the size of most seaborn plots.
#
# You can control the size and aspect ratio of most seaborn grid plots by passing in parameters: size, and aspect. For example:

# %%
# Non Grid Plot
plt.figure(figsize=(12,3))
sns.countplot(x='sex', data=tips, palette='deep')

# %%
# Grid Type Plot
sns.lmplot(x='total_bill', y='tip', data=tips, size=2, aspect=4)

# %% [markdown]
# ## Scale and Context
#
# The set_context() allows you to override default parameters:

# %%
# adjust size for another use case, e.g. a poster
sns.set_context('poster')
sns.countplot(x='sex', data=tips, palette='deep')
# context = paper, notebook, talk, poster

# %%
sns.set_context('poster', font_scale=3)
sns.countplot(x='sex', data=tips, palette='deep')

# %% [markdown]
# Check out the documentation page for more info on these topics:
# https://stanford.edu/~mwaskom/software/seaborn/tutorial/aesthetics.html

# %% [markdown]
# ## Palette
#
# https://matplotlib.org/2.0.2/examples/color/colormaps_reference.html
#
# https://matplotlib.org/tutorials/colors/colormaps.html#sequential
#
# * warm
# * coolwarm
# * magma
# * greys
# * autumn
# * winter
# * deep
# * seimic
